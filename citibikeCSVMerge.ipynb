# %%
##Jersey city csv merge
import pandas as pd

# %%
citibikes_data  = ["data/202208.csv","data/202209.csv","data/202210.csv","data/202211.csv","data/202212.csv"]

# %%
citibikes_list = []

for data in citibikes_data:

    citibikes = pd.read_csv(data)

    citibikes_list.append(citibikes)

    citibikesDF = pd.concat(citibikes_list)

citibikesDF
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      D68047AAA9A72501   classic_bike  2022-08-12 18:14:45
# 1      E5B82A9F588A7650   classic_bike  2022-08-19 01:04:39
# 2      13D19CCBCC9D7B76   classic_bike  2022-08-19 18:13:45
# 3      AA0DBFF220DA98F6   classic_bike  2022-08-21 13:43:05
# 4      8F11D340492FCD32  electric_bike  2022-08-04 22:02:12
# ...                 ...            ...                  ...
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   ended_at                            start_station_name  \
# 0      2022-08-12 18:21:23                                Columbus Drive
# 1      2022-08-19 01:14:10  South Waterfront Walkway - Sinatra Dr & 1 St
# ...

# %%
citibikesDF.dropna(inplace=True)
citibikesDF
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      D68047AAA9A72501   classic_bike  2022-08-12 18:14:45
# 1      E5B82A9F588A7650   classic_bike  2022-08-19 01:04:39
# 2      13D19CCBCC9D7B76   classic_bike  2022-08-19 18:13:45
# 3      AA0DBFF220DA98F6   classic_bike  2022-08-21 13:43:05
# 4      8F11D340492FCD32  electric_bike  2022-08-04 22:02:12
# ...                 ...            ...                  ...
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   ended_at                            start_station_name  \
# 0      2022-08-12 18:21:23                                Columbus Drive
# 1      2022-08-19 01:14:10  South Waterfront Walkway - Sinatra Dr & 1 St
# ...

# %%
citibikesDF.to_csv("data/citibikes_2022_merge.csv", index=False)
